# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/rerkki/data-analytics-ml/refs/heads/main/datasets/PGCB_Demand_Data_2021.csv", encoding='latin-1')
df

# %%
df['date'] = pd.to_datetime(df['date'])
display(df.head())
# Out:
#         date  year  month  day  weekday  hour  demand
# 0 2018-01-01  2018      1    1        2     0  5673.0
# 1 2018-01-01  2018      1    1        2     1  5183.0
# 2 2018-01-01  2018      1    1        2     2  4908.0
# 3 2018-01-01  2018      1    1        2     3  4786.0
# 4 2018-01-01  2018      1    1        2     4  4599.0

# %% [markdown]
# Tässä tehtävässä harjoitellaan aikasarjamallintamista ja -ennustamista vibekoodaamalla. Pyydä Geminiä tekemään ennuste sähkönkulutuksesta vuodelle 2022. Käytä Prophet- tai ARIMA-mallia. Prophet-mallinnus voi kestää useita minuutteja. Palauta mallinnuksesta kuva. Kommentoi myös, mitä muita käyttökohteita ko. menetelmälle keksit esim. automaation/teollisuuden puolelta.
