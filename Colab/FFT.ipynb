# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/rerkki/data-analytics-ml/refs/heads/main/datasets/waveforms.csv", encoding='latin-1')
df

# %% [markdown]
# Tehtävän tarkoitus: Opetellaan ymmärtämään FFT-analyysia ja tulkitsemaan erilaisia taajuussignaaleja. Opetellaan myös vibe-koodausta Geminin avulla.
#
# **Tehtävä:**
#
# Oheinen data sisältää erilaisia taajuusmuotoisia signaaleja (signaalit sarakkeissa s1 - s7, aika sarakkeessa t).
#
# Pyydä Geminiä ensin tekemään signaaleista aikasarjakuvaajat (eli signaalin vaihtelu ajan funktiona). Kommentoi palautukseesi, miten tulkitset kuvaajia. Esim. onko perustaajuuden lisäksi muita signaaleja (kuinka monta), miten taajuus/amplitudi käyttäytyy.
#
# Tämän jälkeen pyydä Geminiä tekemään FFT-analyysi ja taajuustason visualisoinnit signaaleista. Vertaa ja arvioi, miten hyvin aiemmat arviosi pitivät paikkansa.
